# %%
# !pip install langextract
# Out:
# Requirement already satisfied: langextract in c:\users\indraneel\downloads\anaconda\lib\site-packages (1.0.9)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from langextract) (2.3.1)
# Requirement already satisfied: aiohttp>=3.8.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from langextract) (3.10.5)
# Requirement already satisfied: async_timeout>=4.0.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from langextract) (5.0.1)
# Requirement already satisfied: exceptiongroup>=1.1.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from langextract) (1.3.0)
# Requirement already satisfied: google-genai>=0.1.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from langextract) (1.36.0)
# Requirement already satisfied: ml-collections>=0.1.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from langextract) (1.1.0)
# Requirement already satisfied: more-itertools>=8.0.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from langextract) (10.3.0)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from langextract) (1.26.4)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from langextract) (2.3.2)
# Requirement already satisfied: pydantic>=1.8.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from langextract) (2.11.8)
# Requirement already satisfied: python-dotenv>=0.19.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from langextract) (0.21.0)
# Requirement already satisfied: PyYAML>=6.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from langextract) (6.0.1)
# Requirement already satisfied: requests>=2.25.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from langextract) (2.32.3)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from langextract) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from langextract) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from aiohttp>=3.8.0->langextract) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from aiohttp>=3.8.0->langextract) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from aiohttp>=3.8.0->langextract) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from aiohttp>=3.8.0->langextract) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from aiohttp>=3.8.0->langextract) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from aiohttp>=3.8.0->langextract) (1.11.0)
# Requirement already satisfied: idna>=2.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from yarl<2.0,>=1.0->aiohttp>=3.8.0->langextract) (3.7)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from google-genai>=0.1.0->langextract) (4.10.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from google-genai>=0.1.0->langextract) (2.40.3)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from google-genai>=0.1.0->langextract) (0.28.1)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from google-genai>=0.1.0->langextract) (8.2.3)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from google-genai>=0.1.0->langextract) (15.0.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai>=0.1.0->langextract) (1.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai>=0.1.0->langextract) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai>=0.1.0->langextract) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai>=0.1.0->langextract) (4.9.1)
# Requirement already satisfied: certifi in c:\users\indraneel\downloads\anaconda\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai>=0.1.0->langextract) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\indraneel\downloads\anaconda\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai>=0.1.0->langextract) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai>=0.1.0->langextract) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from pydantic>=1.8.0->langextract) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from pydantic>=1.8.0->langextract) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from pydantic>=1.8.0->langextract) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from requests>=2.25.0->langextract) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from requests>=2.25.0->langextract) (1.26.20)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-genai>=0.1.0->langextract) (0.4.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from pandas>=1.3.0->langextract) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from pandas>=1.3.0->langextract) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from pandas>=1.3.0->langextract) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->langextract) (1.16.0)
# Requirement already satisfied: colorama in c:\users\indraneel\downloads\anaconda\lib\site-packages (from tqdm>=4.64.0->langextract) (0.4.6)

# %%
# !pip install docling

from google.colab import files
from docling.document_converter import DocumentConverter
from IPython.display import Markdown, display

# Upload your PDF
uploaded = files.upload()

# Get the uploaded file name
pdf_file = list(uploaded.keys())[0]

# Convert PDF
converter = DocumentConverter()
result = converter.convert(pdf_file)

# Export to markdown
markdown_text = result.document.export_to_markdown()

# Show nicely formatted output
display(Markdown(markdown_text))
# Out:
# Collecting docling
#   Downloading docling-2.55.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from docling) (2.11.8)
# Collecting docling-core<3.0.0,>=2.48.2 (from docling-core[chunking]<3.0.0,>=2.48.2->docling)
#   Downloading docling_core-2.48.4-py3-none-any.whl.metadata (6.5 kB)
# Collecting docling-parse<5.0.0,>=4.4.0 (from docling)
#   Downloading docling_parse-4.5.0-cp312-cp312-win_amd64.whl.metadata (10 kB)
# Collecting docling-ibm-models<4,>=3.9.1 (from docling)
#   Downloading docling_ibm_models-3.9.1-py3-none-any.whl.metadata (6.7 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from docling)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting pypdfium2!=4.30.1,<5.0.0,>=4.30.0 (from docling)
#   Downloading pypdfium2-4.30.0-py3-none-win_amd64.whl.metadata (48 kB)
# Collecting pydantic-settings<3.0.0,>=2.3.0 (from docling)
#   Downloading pydantic_settings-2.11.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: huggingface_hub<1,>=0.23 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from docling) (0.34.4)
# Requirement already satisfied: requests<3.0.0,>=2.32.2 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from docling) (2.32.3)
# Collecting easyocr<2.0,>=1.7 (from docling)
#   Downloading easyocr-1.7.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: certifi>=2024.7.4 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from docling) (2025.8.3)
# Collecting rtree<2.0.0,>=1.3.0 (from docling)
#   Downloading rtree-1.4.1-py3-none-win_amd64.whl.metadata (2.2 kB)
# Collecting typer<0.20.0,>=0.12.5 (from docling)
#   Downloading typer-0.19.2-py3-none-any.whl.metadata (16 kB)
# Collecting python-docx<2.0.0,>=1.1.2 (from docling)
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting python-pptx<2.0.0,>=1.0.2 (from docling)
#   Downloading python_pptx-1.0.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from docling) (4.12.3)
# Requirement already satisfied: pandas<3.0.0,>=2.1.4 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from docling) (2.3.2)
# Collecting marko<3.0.0,>=2.1.2 (from docling)
#   Downloading marko-2.2.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.5 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from docling) (3.1.5)
# Requirement already satisfied: lxml<6.0.0,>=4.0.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from docling) (5.2.1)
# Requirement already satisfied: pillow<12.0.0,>=10.0.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from docling) (10.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.65.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from docling) (4.66.5)
# Requirement already satisfied: pluggy<2.0.0,>=1.0.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from docling) (1.0.0)
# Collecting pylatexenc<3.0,>=2.10 (from docling)
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: scipy<2.0.0,>=1.6.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from docling) (1.13.1)
# Collecting accelerate<2,>=1.0.0 (from docling)
#   Downloading accelerate-1.10.1-py3-none-any.whl.metadata (19 kB)
# Collecting polyfactory>=2.22.2 (from docling)
#   Downloading polyfactory-2.22.2-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from accelerate<2,>=1.0.0->docling) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from accelerate<2,>=1.0.0->docling) (24.1)
# Requirement already satisfied: psutil in c:\users\indraneel\downloads\anaconda\lib\site-packages (from accelerate<2,>=1.0.0->docling) (5.9.0)
# Requirement already satisfied: pyyaml in c:\users\indraneel\downloads\anaconda\lib\site-packages (from accelerate<2,>=1.0.0->docling) (6.0.1)
# Requirement already satisfied: torch>=2.0.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from accelerate<2,>=1.0.0->docling) (2.8.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from accelerate<2,>=1.0.0->docling) (0.6.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->docling) (2.5)
# Requirement already satisfied: jsonschema<5.0.0,>=4.16.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from docling-core<3.0.0,>=2.48.2->docling-core[chunking]<3.0.0,>=2.48.2->docling) (4.23.0)
# Collecting jsonref<2.0.0,>=1.1.0 (from docling-core<3.0.0,>=2.48.2->docling-core[chunking]<3.0.0,>=2.48.2->docling)
#   Downloading jsonref-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from docling-core<3.0.0,>=2.48.2->docling-core[chunking]<3.0.0,>=2.48.2->docling) (0.9.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.12.2 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from docling-core<3.0.0,>=2.48.2->docling-core[chunking]<3.0.0,>=2.48.2->docling) (4.15.0)
# Collecting latex2mathml<4.0.0,>=3.77.0 (from docling-core<3.0.0,>=2.48.2->docling-core[chunking]<3.0.0,>=2.48.2->docling)
#   Downloading latex2mathml-3.78.1-py3-none-any.whl.metadata (15 kB)
# Collecting semchunk<3.0.0,>=2.2.0 (from docling-core[chunking]<3.0.0,>=2.48.2->docling)
#   Downloading semchunk-2.2.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from docling-core[chunking]<3.0.0,>=2.48.2->docling) (4.55.2)
# Requirement already satisfied: torchvision<1,>=0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from docling-ibm-models<4,>=3.9.1->docling) (0.23.0)
# Collecting jsonlines<4.0.0,>=3.1.0 (from docling-ibm-models<4,>=3.9.1->docling)
#   Downloading jsonlines-3.1.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting opencv-python-headless<5.0.0.0,>=4.6.0.66 (from docling-ibm-models<4,>=3.9.1->docling)
#   Downloading opencv_python_headless-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: pywin32>=305 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from docling-parse<5.0.0,>=4.4.0->docling) (305.1)
# Requirement already satisfied: scikit-image in c:\users\indraneel\downloads\anaconda\lib\site-packages (from easyocr<2.0,>=1.7->docling) (0.24.0)
# Collecting python-bidi (from easyocr<2.0,>=1.7->docling)
#   Downloading python_bidi-0.6.6-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Collecting Shapely (from easyocr<2.0,>=1.7->docling)
#   Downloading shapely-2.1.2-cp312-cp312-win_amd64.whl.metadata (7.1 kB)
# Collecting pyclipper (from easyocr<2.0,>=1.7->docling)
#   Downloading pyclipper-1.3.0.post6-cp312-cp312-win_amd64.whl.metadata (9.2 kB)
# Collecting ninja (from easyocr<2.0,>=1.7->docling)
#   Downloading ninja-1.13.0-py3-none-win_amd64.whl.metadata (5.1 kB)
# Requirement already satisfied: filelock in c:\users\indraneel\downloads\anaconda\lib\site-packages (from huggingface_hub<1,>=0.23->docling) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from huggingface_hub<1,>=0.23->docling) (2024.6.1)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from jsonlines<4.0.0,>=3.1.0->docling-ibm-models<4,>=3.9.1->docling) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.48.2->docling-core[chunking]<3.0.0,>=2.48.2->docling) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.48.2->docling-core[chunking]<3.0.0,>=2.48.2->docling) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.48.2->docling-core[chunking]<3.0.0,>=2.48.2->docling) (0.10.6)
# Collecting numpy<3.0.0,>=1.17 (from accelerate<2,>=1.0.0->docling)
#   Using cached numpy-2.2.6-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: et-xmlfile in c:\users\indraneel\downloads\anaconda\lib\site-packages (from openpyxl<4.0.0,>=3.1.5->docling) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from pandas<3.0.0,>=2.1.4->docling) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from pandas<3.0.0,>=2.1.4->docling) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from pandas<3.0.0,>=2.1.4->docling) (2023.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.0.0->docling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.0.0->docling) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.0.0->docling) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from pydantic-settings<3.0.0,>=2.3.0->docling) (0.21.0)
# Collecting XlsxWriter>=0.5.7 (from python-pptx<2.0.0,>=1.0.2->docling)
#   Downloading xlsxwriter-3.2.9-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from requests<3.0.0,>=2.32.2->docling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from requests<3.0.0,>=2.32.2->docling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from requests<3.0.0,>=2.32.2->docling) (1.26.20)
# Collecting mpire[dill] (from semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.48.2->docling)
#   Downloading mpire-2.10.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling) (1.14.0)
# Requirement already satisfied: networkx in c:\users\indraneel\downloads\anaconda\lib\site-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling) (3.3)
# Requirement already satisfied: jinja2 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\indraneel\downloads\anaconda\lib\site-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling) (80.9.0)
# Requirement already satisfied: colorama in c:\users\indraneel\downloads\anaconda\lib\site-packages (from tqdm<5.0.0,>=4.65.0->docling) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from transformers<5.0.0,>=4.34.0->docling-core[chunking]<3.0.0,>=2.48.2->docling) (2024.9.11)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from transformers<5.0.0,>=4.34.0->docling-core[chunking]<3.0.0,>=2.48.2->docling) (0.21.4)
# Requirement already satisfied: click>=8.0.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from typer<0.20.0,>=0.12.5->docling) (8.1.7)
# Collecting shellingham>=1.3.0 (from typer<0.20.0,>=0.12.5->docling)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: rich>=10.11.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from typer<0.20.0,>=0.12.5->docling) (13.7.1)
# Requirement already satisfied: faker>=5.0.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from polyfactory>=2.22.2->docling) (37.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.1.4->docling) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from rich>=10.11.0->typer<0.20.0,>=0.12.5->docling) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from rich>=10.11.0->typer<0.20.0,>=0.12.5->docling) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<0.20.0,>=0.12.5->docling) (0.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate<2,>=1.0.0->docling) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from jinja2->torch>=2.0.0->accelerate<2,>=1.0.0->docling) (2.1.3)
# Requirement already satisfied: multiprocess>=0.70.15 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from mpire[dill]->semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.48.2->docling) (0.70.16)
# Requirement already satisfied: dill>=0.3.8 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from multiprocess>=0.70.15->mpire[dill]->semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.48.2->docling) (0.3.8)
# Requirement already satisfied: imageio>=2.33 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from scikit-image->easyocr<2.0,>=1.7->docling) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from scikit-image->easyocr<2.0,>=1.7->docling) (2023.4.12)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\indraneel\downloads\anaconda\lib\site-packages (from scikit-image->easyocr<2.0,>=1.7->docling) (0.4)
# Downloading docling-2.55.0-py3-none-any.whl (238 kB)
# Downloading accelerate-1.10.1-py3-none-any.whl (374 kB)
# Downloading docling_core-2.48.4-py3-none-any.whl (164 kB)
# Downloading docling_ibm_models-3.9.1-py3-none-any.whl (86 kB)
# Downloading docling_parse-4.5.0-cp312-cp312-win_amd64.whl (16.1 MB)
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
#    -- ------------------------------------- 1.0/16.1 MB 6.3 MB/s eta 0:00:03
#    --- ------------------------------------ 1.3/16.1 MB 3.2 MB/s eta 0:00:05
#    ------ --------------------------------- 2.6/16.1 MB 4.0 MB/s eta 0:00:04
#    -------- ------------------------------- 3.4/16.1 MB 3.8 MB/s eta 0:00:04
#    ---------- ----------------------------- 4.2/16.1 MB 3.9 MB/s eta 0:00:04
#    ------------ --------------------------- 5.0/16.1 MB 3.9 MB/s eta 0:00:03
#    -------------- ------------------------- 5.8/16.1 MB 3.9 MB/s eta 0:00:03
#    ---------------- ----------------------- 6.8/16.1 MB 3.9 MB/s eta 0:00:03
#    ------------------ --------------------- 7.6/16.1 MB 3.9 MB/s eta 0:00:03
#    -------------------- ------------------- 8.4/16.1 MB 3.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 9.2/16.1 MB 3.9 MB/s eta 0:00:02
#    ------------------------ --------------- 10.0/16.1 MB 3.9 MB/s eta 0:00:02
#    -------------------------- ------------- 10.7/16.1 MB 3.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 11.8/16.1 MB 3.9 MB/s eta 0:00:02
#    ------------------------------- -------- 12.6/16.1 MB 3.9 MB/s eta 0:00:01
#    --------------------------------- ------ 13.4/16.1 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.2/16.1 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------- -- 14.9/16.1 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  15.7/16.1 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 16.1/16.1 MB 3.8 MB/s  0:00:04
# Downloading easyocr-1.7.2-py3-none-any.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    -------------- ------------------------- 1.0/2.9 MB 5.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.1/2.9 MB 4.7 MB/s eta 0:00:01
#    ------------------------------------ --- 2.6/2.9 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 4.1 MB/s  0:00:00
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading jsonlines-3.1.0-py3-none-any.whl (8.6 kB)
# Downloading jsonref-1.1.0-py3-none-any.whl (9.4 kB)
# Downloading latex2mathml-3.78.1-py3-none-any.whl (73 kB)
# Downloading marko-2.2.0-py3-none-any.whl (42 kB)
# Downloading opencv_python_headless-4.12.0.88-cp37-abi3-win_amd64.whl (38.9 MB)
#    ---------------------------------------- 0.0/38.9 MB ? eta -:--:--
#    - -------------------------------------- 1.0/38.9 MB 5.0 MB/s eta 0:00:08
#    - -------------------------------------- 1.8/38.9 MB 4.4 MB/s eta 0:00:09
#    -- ------------------------------------- 2.9/38.9 MB 4.2 MB/s eta 0:00:09
#    --- ------------------------------------ 3.7/38.9 MB 4.1 MB/s eta 0:00:09
#    ---- ----------------------------------- 4.5/38.9 MB 4.1 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.2/38.9 MB 4.0 MB/s eta 0:00:09
#    ------ --------------------------------- 6.0/38.9 MB 4.0 MB/s eta 0:00:09
#    ------- -------------------------------- 7.1/38.9 MB 4.0 MB/s eta 0:00:08
#    -------- ------------------------------- 7.9/38.9 MB 4.0 MB/s eta 0:00:08
#    -------- ------------------------------- 8.7/38.9 MB 4.0 MB/s eta 0:00:08
#    --------- ------------------------------ 9.4/38.9 MB 4.0 MB/s eta 0:00:08
#    ---------- ----------------------------- 10.2/38.9 MB 4.0 MB/s eta 0:00:08
#    ----------- ---------------------------- 11.0/38.9 MB 4.0 MB/s eta 0:00:08
#    ------------ --------------------------- 12.1/38.9 MB 4.0 MB/s eta 0:00:07
#    ------------- -------------------------- 12.8/38.9 MB 3.9 MB/s eta 0:00:07
#    -------------- ------------------------- 13.6/38.9 MB 3.9 MB/s eta 0:00:07
#    -------------- ------------------------- 14.4/38.9 MB 3.9 MB/s eta 0:00:07
#    --------------- ------------------------ 15.2/38.9 MB 3.9 MB/s eta 0:00:07
#    ---------------- ----------------------- 16.3/38.9 MB 3.9 MB/s eta 0:00:06
#    ----------------- ---------------------- 17.0/38.9 MB 3.9 MB/s eta 0:00:06
#    ------------------ --------------------- 17.6/38.9 MB 3.9 MB/s eta 0:00:06
#    ------------------- -------------------- 18.6/38.9 MB 3.9 MB/s eta 0:00:06
#    ------------------- -------------------- 19.4/38.9 MB 3.9 MB/s eta 0:00:05
#    -------------------- ------------------- 20.2/38.9 MB 3.9 MB/s eta 0:00:05
#    --------------------- ------------------ 21.2/38.9 MB 3.9 MB/s eta 0:00:05
#    ---------------------- ----------------- 22.0/38.9 MB 3.9 MB/s eta 0:00:05
#    ----------------------- ---------------- 22.8/38.9 MB 3.9 MB/s eta 0:00:05
#    ----------------------- ---------------- 23.3/38.9 MB 3.9 MB/s eta 0:00:05
#    ------------------------ --------------- 24.1/38.9 MB 3.9 MB/s eta 0:00:04
#    ------------------------- -------------- 25.2/38.9 MB 3.9 MB/s eta 0:00:04
#    -------------------------- ------------- 26.0/38.9 MB 3.9 MB/s eta 0:00:04
#    --------------------------- ------------ 26.7/38.9 MB 3.9 MB/s eta 0:00:04
#    ---------------------------- ----------- 27.5/38.9 MB 3.9 MB/s eta 0:00:03
#    ----------------------------- ---------- 28.3/38.9 MB 3.9 MB/s eta 0:00:03
#    ----------------------------- ---------- 29.1/38.9 MB 3.9 MB/s eta 0:00:03
#    ------------------------------ --------- 30.1/38.9 MB 3.9 MB/s eta 0:00:03
#    ------------------------------- -------- 30.9/38.9 MB 3.9 MB/s eta 0:00:03
#    -------------------------------- ------- 31.7/38.9 MB 3.9 MB/s eta 0:00:02
#    --------------------------------- ------ 32.5/38.9 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.3/38.9 MB 3.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.3/38.9 MB 3.9 MB/s eta 0:00:02
#    ------------------------------------ --- 35.1/38.9 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------ --- 35.9/38.9 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------- -- 36.7/38.9 MB 3.9 MB/s eta 0:00:01
#    -------------------------------------- - 37.5/38.9 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.9 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  38.8/38.9 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 38.9/38.9 MB 3.8 MB/s  0:00:10
# Using cached numpy-2.2.6-cp312-cp312-win_amd64.whl (12.6 MB)
# Downloading pydantic_settings-2.11.0-py3-none-any.whl (48 kB)
# Downloading pypdfium2-4.30.0-py3-none-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    -------------- ------------------------- 1.0/2.9 MB 5.6 MB/s eta 0:00:01
#    ------------------------- -------------- 1.8/2.9 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  2.9/2.9 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 4.0 MB/s  0:00:00
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
# Downloading python_pptx-1.0.2-py3-none-any.whl (472 kB)
# Downloading rtree-1.4.1-py3-none-win_amd64.whl (389 kB)
# Downloading semchunk-2.2.2-py3-none-any.whl (10 kB)
# Downloading typer-0.19.2-py3-none-any.whl (46 kB)
# Downloading polyfactory-2.22.2-py3-none-any.whl (63 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading xlsxwriter-3.2.9-py3-none-any.whl (175 kB)
# Downloading mpire-2.10.2-py3-none-any.whl (272 kB)
# Downloading ninja-1.13.0-py3-none-win_amd64.whl (309 kB)
# Downloading pyclipper-1.3.0.post6-cp312-cp312-win_amd64.whl (110 kB)
# Downloading python_bidi-0.6.6-cp312-cp312-win_amd64.whl (160 kB)
# Downloading shapely-2.1.2-cp312-cp312-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------------ --------------- 1.0/1.7 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 4.3 MB/s  0:00:00
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py): started
#   Building wheel for pylatexenc (setup.py): finished with status 'done'
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136928 sha256=c18af52dddd4fac29aa2da9afbae109f7df1348470eb1638b24bc2d3aaf2c29d
#   Stored in directory: c:\users\indraneel\appdata\local\pip\cache\wheels\06\3e\78\fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# Installing collected packages: python-bidi, pylatexenc, pyclipper, filetype, XlsxWriter, shellingham, rtree, python-docx, pypdfium2, numpy, ninja, marko, latex2mathml, jsonref, jsonlines, Shapely, python-pptx, polyfactory, opencv-python-headless, mpire, typer, pydantic-settings, accelerate, semchunk, easyocr, docling-core, docling-parse, docling-ibm-models, docling
#
#    ----------------------------------------  0/29 [python-bidi]
#    ----------------------------------------  0/29 [python-bidi]
#    - --------------------------------------  1/29 [pylatexenc]
#    - --------------------------------------  1/29 [pylatexenc]
#    - --------------------------------------  1/29 [pylatexenc]
#    - --------------------------------------  1/29 [pylatexenc]
#    - --------------------------------------  1/29 [pylatexenc]
#    - --------------------------------------  1/29 [pylatexenc]
#    - --------------------------------------  1/29 [pylatexenc]
#    - --------------------------------------  1/29 [pylatexenc]
#    ---- -----------------------------------  3/29 [filetype]
#    ---- -----------------------------------  3/29 [filetype]
#    ---- -----------------------------------  3/29 [filetype]
#    ---- -----------------------------------  3/29 [filetype]
#    ---- -----------------------------------  3/29 [filetype]
#    ---- -----------------------------------  3/29 [filetype]
#    ----- ----------------------------------  4/29 [XlsxWriter]
#    ----- ----------------------------------  4/29 [XlsxWriter]
#    ----- ----------------------------------  4/29 [XlsxWriter]
#    ----- ----------------------------------  4/29 [XlsxWriter]
#    ----- ----------------------------------  4/29 [XlsxWriter]
#    ----- ----------------------------------  4/29 [XlsxWriter]
#    ----- ----------------------------------  4/29 [XlsxWriter]
#    ----- ----------------------------------  4/29 [XlsxWriter]
#    ----- ----------------------------------  4/29 [XlsxWriter]
#    ----- ----------------------------------  4/29 [XlsxWriter]
#    ----- ----------------------------------  4/29 [XlsxWriter]
#    ------ ---------------------------------  5/29 [shellingham]
#   Attempting uninstall: rtree
#    ------ ---------------------------------  5/29 [shellingham]
#    -------- -------------------------------  6/29 [rtree]
#     Found existing installation: Rtree 1.0.1
#    -------- -------------------------------  6/29 [rtree]
#     Uninstalling Rtree-1.0.1:
#    -------- -------------------------------  6/29 [rtree]
#       Successfully uninstalled Rtree-1.0.1
#    -------- -------------------------------  6/29 [rtree]
#    -------- -------------------------------  6/29 [rtree]
#    -------- -------------------------------  6/29 [rtree]
#    --------- ------------------------------  7/29 [python-docx]
#    --------- ------------------------------  7/29 [python-docx]
#    --------- ------------------------------  7/29 [python-docx]
#    --------- ------------------------------  7/29 [python-docx]
#    --------- ------------------------------  7/29 [python-docx]
#    --------- ------------------------------  7/29 [python-docx]
#    --------- ------------------------------  7/29 [python-docx]
#    --------- ------------------------------  7/29 [python-docx]
#    --------- ------------------------------  7/29 [python-docx]
#    --------- ------------------------------  7/29 [python-docx]
#    --------- ------------------------------  7/29 [python-docx]
#    --------- ------------------------------  7/29 [python-docx]
#    --------- ------------------------------  7/29 [python-docx]
#    --------- ------------------------------  7/29 [python-docx]
#    --------- ------------------------------  7/29 [python-docx]
#    --------- ------------------------------  7/29 [python-docx]
#    --------- ------------------------------  7/29 [python-docx]
#    --------- ------------------------------  7/29 [python-docx]
#    --------- ------------------------------  7/29 [python-docx]
#    --------- ------------------------------  7/29 [python-docx]
#    ----------- ----------------------------  8/29 [pypdfium2]
#    ----------- ----------------------------  8/29 [pypdfium2]
#    ----------- ----------------------------  8/29 [pypdfium2]
#    ----------- ----------------------------  8/29 [pypdfium2]
#    ----------- ----------------------------  8/29 [pypdfium2]
#    ----------- ----------------------------  8/29 [pypdfium2]
#    ----------- ----------------------------  8/29 [pypdfium2]
#    ----------- ----------------------------  8/29 [pypdfium2]
#    ----------- ----------------------------  8/29 [pypdfium2]
#   Attempting uninstall: numpy
#    ----------- ----------------------------  8/29 [pypdfium2]
#     Found existing installation: numpy 1.26.4
#    ----------- ----------------------------  8/29 [pypdfium2]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#     Uninstalling numpy-1.26.4:
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#       Successfully uninstalled numpy-1.26.4
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------ ---------------------------  9/29 [numpy]
#    ------------- -------------------------- 10/29 [ninja]
#    ------------- -------------------------- 10/29 [ninja]
#    --------------- ------------------------ 11/29 [marko]
#    --------------- ------------------------ 11/29 [marko]
#    --------------- ------------------------ 11/29 [marko]
#    --------------- ------------------------ 11/29 [marko]
#    --------------- ------------------------ 11/29 [marko]
#    --------------- ------------------------ 11/29 [marko]
#    --------------- ------------------------ 11/29 [marko]
#    ---------------- ----------------------- 12/29 [latex2mathml]
#    ---------------- ----------------------- 12/29 [latex2mathml]
#    ---------------- ----------------------- 12/29 [latex2mathml]
#    ----------------- ---------------------- 13/29 [jsonref]
#    ------------------- -------------------- 14/29 [jsonlines]
#    -------------------- ------------------- 15/29 [Shapely]
#    -------------------- ------------------- 15/29 [Shapely]
#    -------------------- ------------------- 15/29 [Shapely]
#    -------------------- ------------------- 15/29 [Shapely]
#    -------------------- ------------------- 15/29 [Shapely]
#    -------------------- ------------------- 15/29 [Shapely]
#    -------------------- ------------------- 15/29 [Shapely]
#    -------------------- ------------------- 15/29 [Shapely]
#    -------------------- ------------------- 15/29 [Shapely]
#    -------------------- ------------------- 15/29 [Shapely]
#    -------------------- ------------------- 15/29 [Shapely]
#    -------------------- ------------------- 15/29 [Shapely]
#    -------------------- ------------------- 15/29 [Shapely]
#    -------------------- ------------------- 15/29 [Shapely]
#    -------------------- ------------------- 15/29 [Shapely]
#    -------------------- ------------------- 15/29 [Shapely]
#    -------------------- ------------------- 15/29 [Shapely]
#    -------------------- ------------------- 15/29 [Shapely]
#    -------------------- ------------------- 15/29 [Shapely]
#    -------------------- ------------------- 15/29 [Shapely]
#    -------------------- ------------------- 15/29 [Shapely]
#    -------------------- ------------------- 15/29 [Shapely]
#    -------------------- ------------------- 15/29 [Shapely]
#    -------------------- ------------------- 15/29 [Shapely]
#    -------------------- ------------------- 15/29 [Shapely]
#    -------------------- ------------------- 15/29 [Shapely]
#    ---------------------- ----------------- 16/29 [python-pptx]
#    ---------------------- ----------------- 16/29 [python-pptx]
#    ---------------------- ----------------- 16/29 [python-pptx]
#    ---------------------- ----------------- 16/29 [python-pptx]
#    ---------------------- ----------------- 16/29 [python-pptx]
#    ---------------------- ----------------- 16/29 [python-pptx]
#    ---------------------- ----------------- 16/29 [python-pptx]
#    ---------------------- ----------------- 16/29 [python-pptx]
#    ---------------------- ----------------- 16/29 [python-pptx]
#    ---------------------- ----------------- 16/29 [python-pptx]
#    ---------------------- ----------------- 16/29 [python-pptx]
#    ---------------------- ----------------- 16/29 [python-pptx]
#    ---------------------- ----------------- 16/29 [python-pptx]
#    ---------------------- ----------------- 16/29 [python-pptx]
#    ---------------------- ----------------- 16/29 [python-pptx]
#    ---------------------- ----------------- 16/29 [python-pptx]
#    ---------------------- ----------------- 16/29 [python-pptx]
#    ---------------------- ----------------- 16/29 [python-pptx]
#    ---------------------- ----------------- 16/29 [python-pptx]
#    ---------------------- ----------------- 16/29 [python-pptx]
#    ---------------------- ----------------- 16/29 [python-pptx]
#    ----------------------- ---------------- 17/29 [polyfactory]
#    ----------------------- ---------------- 17/29 [polyfactory]
#    ----------------------- ---------------- 17/29 [polyfactory]
#    ----------------------- ---------------- 17/29 [polyfactory]
#    ----------------------- ---------------- 17/29 [polyfactory]
#    ----------------------- ---------------- 17/29 [polyfactory]
#    ----------------------- ---------------- 17/29 [polyfactory]
#    ----------------------- ---------------- 17/29 [polyfactory]
#    ----------------------- ---------------- 17/29 [polyfactory]
#    ------------------------ --------------- 18/29 [opencv-python-headless]
#    ------------------------ --------------- 18/29 [opencv-python-headless]
#    ------------------------ --------------- 18/29 [opencv-python-headless]
#    ------------------------ --------------- 18/29 [opencv-python-headless]
#    ------------------------ --------------- 18/29 [opencv-python-headless]
#    ------------------------ --------------- 18/29 [opencv-python-headless]
#    ------------------------ --------------- 18/29 [opencv-python-headless]
#    ------------------------ --------------- 18/29 [opencv-python-headless]
#    ------------------------ --------------- 18/29 [opencv-python-headless]
#    ------------------------ --------------- 18/29 [opencv-python-headless]
#    ------------------------ --------------- 18/29 [opencv-python-headless]
#    ------------------------ --------------- 18/29 [opencv-python-headless]
#    -------------------------- ------------- 19/29 [mpire]
#    -------------------------- ------------- 19/29 [mpire]
#    -------------------------- ------------- 19/29 [mpire]
#    -------------------------- ------------- 19/29 [mpire]
#    -------------------------- ------------- 19/29 [mpire]
#    --------------------------- ------------ 20/29 [typer]
#    --------------------------- ------------ 20/29 [typer]
#    --------------------------- ------------ 20/29 [typer]
#    --------------------------- ------------ 20/29 [typer]
#    --------------------------- ------------ 20/29 [typer]
#    ---------------------------- ----------- 21/29 [pydantic-settings]
#    ---------------------------- ----------- 21/29 [pydantic-settings]
#    ---------------------------- ----------- 21/29 [pydantic-settings]
#    ---------------------------- ----------- 21/29 [pydantic-settings]
#    ------------------------------ --------- 22/29 [accelerate]
#    ------------------------------ --------- 22/29 [accelerate]
#    ------------------------------ --------- 22/29 [accelerate]
#    ------------------------------ --------- 22/29 [accelerate]
#    ------------------------------ --------- 22/29 [accelerate]
#    ------------------------------ --------- 22/29 [accelerate]
#    ------------------------------ --------- 22/29 [accelerate]
#    ------------------------------ --------- 22/29 [accelerate]
#    ------------------------------ --------- 22/29 [accelerate]
#    ------------------------------ --------- 22/29 [accelerate]
#    ------------------------------ --------- 22/29 [accelerate]
#    ------------------------------ --------- 22/29 [accelerate]
#    ------------------------------ --------- 22/29 [accelerate]
#    ------------------------------ --------- 22/29 [accelerate]
#    ------------------------------ --------- 22/29 [accelerate]
#    ------------------------------ --------- 22/29 [accelerate]
#    ------------------------------ --------- 22/29 [accelerate]
#    ------------------------------ --------- 22/29 [accelerate]
#    ------------------------------ --------- 22/29 [accelerate]
#    ------------------------------ --------- 22/29 [accelerate]
#    ------------------------------ --------- 22/29 [accelerate]
#    ------------------------------ --------- 22/29 [accelerate]
#    ------------------------------ --------- 22/29 [accelerate]
#    ------------------------------ --------- 22/29 [accelerate]
#    ------------------------------ --------- 22/29 [accelerate]
#    ------------------------------ --------- 22/29 [accelerate]
#    ------------------------------ --------- 22/29 [accelerate]
#    --------------------------------- ------ 24/29 [easyocr]
#    --------------------------------- ------ 24/29 [easyocr]
#    --------------------------------- ------ 24/29 [easyocr]
#    --------------------------------- ------ 24/29 [easyocr]
#    --------------------------------- ------ 24/29 [easyocr]
#    --------------------------------- ------ 24/29 [easyocr]
#    --------------------------------- ------ 24/29 [easyocr]
#    --------------------------------- ------ 24/29 [easyocr]
#    --------------------------------- ------ 24/29 [easyocr]
#    --------------------------------- ------ 24/29 [easyocr]
#    --------------------------------- ------ 24/29 [easyocr]
#    --------------------------------- ------ 24/29 [easyocr]
#    ---------------------------------- ----- 25/29 [docling-core]
#    ---------------------------------- ----- 25/29 [docling-core]
#    ---------------------------------- ----- 25/29 [docling-core]
#    ---------------------------------- ----- 25/29 [docling-core]
#    ---------------------------------- ----- 25/29 [docling-core]
#    ---------------------------------- ----- 25/29 [docling-core]
#    ---------------------------------- ----- 25/29 [docling-core]
#    ---------------------------------- ----- 25/29 [docling-core]
#    ---------------------------------- ----- 25/29 [docling-core]
#    ---------------------------------- ----- 25/29 [docling-core]
#    ---------------------------------- ----- 25/29 [docling-core]
#    ---------------------------------- ----- 25/29 [docling-core]
#    ---------------------------------- ----- 25/29 [docling-core]
#    ---------------------------------- ----- 25/29 [docling-core]
#    ---------------------------------- ----- 25/29 [docling-core]
#    ---------------------------------- ----- 25/29 [docling-core]
#    ----------------------------------- ---- 26/29 [docling-parse]
#    ----------------------------------- ---- 26/29 [docling-parse]
#    ----------------------------------- ---- 26/29 [docling-parse]
#    ----------------------------------- ---- 26/29 [docling-parse]
#    ----------------------------------- ---- 26/29 [docling-parse]
#    ----------------------------------- ---- 26/29 [docling-parse]
#    ----------------------------------- ---- 26/29 [docling-parse]
#    ----------------------------------- ---- 26/29 [docling-parse]
#    ----------------------------------- ---- 26/29 [docling-parse]
#    ----------------------------------- ---- 26/29 [docling-parse]
#    ----------------------------------- ---- 26/29 [docling-parse]
#    ----------------------------------- ---- 26/29 [docling-parse]
#    ----------------------------------- ---- 26/29 [docling-parse]
#    ----------------------------------- ---- 26/29 [docling-parse]
#    ----------------------------------- ---- 26/29 [docling-parse]
#    ------------------------------------- -- 27/29 [docling-ibm-models]
#    ------------------------------------- -- 27/29 [docling-ibm-models]
#    ------------------------------------- -- 27/29 [docling-ibm-models]
#    ------------------------------------- -- 27/29 [docling-ibm-models]
#    ------------------------------------- -- 27/29 [docling-ibm-models]
#    ------------------------------------- -- 27/29 [docling-ibm-models]
#    -------------------------------------- - 28/29 [docling]
#    -------------------------------------- - 28/29 [docling]
#    -------------------------------------- - 28/29 [docling]
#    -------------------------------------- - 28/29 [docling]
#    -------------------------------------- - 28/29 [docling]
#    -------------------------------------- - 28/29 [docling]
#    -------------------------------------- - 28/29 [docling]
#    -------------------------------------- - 28/29 [docling]
#    -------------------------------------- - 28/29 [docling]
#    -------------------------------------- - 28/29 [docling]
#    -------------------------------------- - 28/29 [docling]
#    -------------------------------------- - 28/29 [docling]
#    -------------------------------------- - 28/29 [docling]
#    -------------------------------------- - 28/29 [docling]
#    -------------------------------------- - 28/29 [docling]
#    -------------------------------------- - 28/29 [docling]
#    -------------------------------------- - 28/29 [docling]
#    -------------------------------------- - 28/29 [docling]
#    -------------------------------------- - 28/29 [docling]
#    -------------------------------------- - 28/29 [docling]
#    -------------------------------------- - 28/29 [docling]
#    -------------------------------------- - 28/29 [docling]
#    -------------------------------------- - 28/29 [docling]
#    ---------------------------------------- 29/29 [docling]
#
# Successfully installed Shapely-2.1.2 XlsxWriter-3.2.9 accelerate-1.10.1 docling-2.55.0 docling-core-2.48.4 docling-ibm-models-3.9.1 docling-parse-4.5.0 easyocr-1.7.2 filetype-1.2.0 jsonlines-3.1.0 jsonref-1.1.0 latex2mathml-3.78.1 marko-2.2.0 mpire-2.10.2 ninja-1.13.0 numpy-2.2.6 opencv-python-headless-4.12.0.88 polyfactory-2.22.2 pyclipper-1.3.0.post6 pydantic-settings-2.11.0 pylatexenc-2.10 pypdfium2-4.30.0 python-bidi-0.6.6 python-docx-1.2.0 python-pptx-1.0.2 rtree-1.4.1 semchunk-2.2.2 shellingham-1.5.4 typer-0.19.2
#   DEPRECATION: Building 'pylatexenc' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'pylatexenc'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.2.6 which is incompatible.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.2.6 which is incompatible.
# label-studio 1.20.0 requires numpy<2.0.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.
# streamlit 1.37.1 requires protobuf<6,>=3.20, but you have protobuf 6.32.0 which is incompatible.
# tensorflow 2.20.0 requires tensorboard~=2.20.0, but you have tensorboard 2.18.0 which is incompatible.
# tensorflow-cpu 2.18.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.32.0 which is incompatible.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 get_ipython().system('pip install docling')
# ----> 3 from google.colab import files
#       4 from docling.document_converter import DocumentConverter
#       5 from IPython.display import Markdown, display
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
import langextract as lx
import textwrap

prompt = textwrap.dedent("""\
    Extract the following entities in order of appearance:
    - ORGANIZATION (company, bank, firm, institution)
    - PERSON (individuals named in the document)
    - DATE (contract dates, deadlines, durations)
    - MONEY (loans, amounts, salaries, payments)
    - PERCENT (interest rates, growth rates, percentages)
    - ACCOUNT_NUMBER (bank accounts, policy numbers, transaction IDs)
    - ROLE (positions like Director, Manager, Borrower, Lender)
    - CONTRACT_REFERENCE (Agreement, Clause, Section references)
    - LOCATION (cities, offices, addresses)

""")

# %%
import langextract as lx

# Initialize the examples list
examples = []

# 6. Completely different financial example
examples.append(
    lx.data.ExampleData(
        text="On February 5, 2025, SBI Credit Card processed a payment of ₹12,450 for Ramesh Verma at Amazon India, Bengaluru, under Transaction ID TXN-778899. The payment was made using Card No. 4111-5678-9012-3456 with a cashback offer of 5%.",
        extractions=[
            lx.data.Extraction(
                extraction_class="DATE",
                extraction_text="February 5, 2025",
                attributes={"type": "transaction_date"}
            ),
            lx.data.Extraction(
                extraction_class="ORG",
                extraction_text="SBI Credit Card",
                attributes={"industry": "financial services"}
            ),
            lx.data.Extraction(
                extraction_class="MONEY",
                extraction_text="₹12,450",
                attributes={"currency": "INR", "purpose": "online purchase"}
            ),
            lx.data.Extraction(
                extraction_class="PERSON",
                extraction_text="Ramesh Verma",
                attributes={"role": "cardholder"}
            ),
            lx.data.Extraction(
                extraction_class="ROLE",
                extraction_text="Cardholder",
                attributes={"relation": "payment initiator"}
            ),
            lx.data.Extraction(
                extraction_class="LOCATION",
                extraction_text="Bengaluru",
                attributes={"type": "merchant_location"}
            ),
            lx.data.Extraction(
                extraction_class="CONTRACT_REFERENCE",
                extraction_text="Transaction ID TXN-778899",
                attributes={"type": "transaction_reference"}
            ),
            lx.data.Extraction(
                extraction_class="ACCOUNT_NUMBER",
                extraction_text="4111-5678-9012-3456",
                attributes={"type": "credit_card_number"}
            ),
            lx.data.Extraction(
                extraction_class="PERCENT",
                extraction_text="5%",
                attributes={"type": "cashback_offer"}
            ),
        ]
    )
)

# %%
result = lx.extract(
    text_or_documents=markdown_text,
    prompt_description=prompt,
    examples=examples,
    model_id="gemini-2.5-flash",
    api_key="GOOGLE_API_KEY",
    extraction_passes=3,
    max_workers=20,
    max_char_buffer=1000
)

print(result)
# Out:
# WARNING:absl:Prompt alignment: FAILED to align: [example#0] class='ROLE' status=None text='Cardholder'
# WARNING:absl:Prompt alignment: non-exact match: [example#0] class='PERCENT' status=AlignmentStatus.MATCH_LESSER text='5%' char_span=(227, 228)
# /usr/local/lib/python3.12/dist-packages/langextract/extraction.py:186: UserWarning: batch_length (10) < max_workers (20). Only 10 workers will be used. Set batch_length >= max_workers for optimal parallelization.
#   warnings.warn(
# AnnotatedDocument(extractions=[Extraction(extraction_class='DATE', extraction_text='2 nd April, 2025', char_interval=CharInterval(start_pos=0, end_pos=16), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=1, group_index=0, description=None, attributes={'type': 'event_date'}), Extraction(extraction_class='LOCATION', extraction_text='Accra', char_interval=CharInterval(start_pos=17, end_pos=22), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=2, group_index=1, description=None, attributes={'type': 'city'}), Extraction(extraction_class='ORG', extraction_text='Government of Ghana', char_interval=CharInterval(start_pos=27, end_pos=46), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=3, group_index=2, description=None, attributes={'industry': 'government'}), Extraction(extraction_class='ORG', extraction_text='World Bank', char_interval=CharInterval(start_pos=222, end_pos=232), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=4, group_index=3, description=None, attributes={'industry': 'financial services'}), Extraction(extraction_class='ROLE', extraction_text='professionals', char_interval=CharInterval(start_pos=324, end_pos=337), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=5, group_index=4, description=None, attributes={'relation': 'forum participant'}), Extraction(extraction_class='ROLE', extraction_text='interested persons', char_interval=CharInterval(start_pos=342, end_pos=360), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=6, group_index=5, description=None, attributes={'relation': 'forum participant'}), Extraction(extraction_class='LOCATION', extraction_text='Ghana', char_interval=CharInterval(start_pos=519, end_pos=524), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=7, group_index=6, description=None, attributes={'type': 'country'}), Extraction(extraction_class='LOCATION', extraction_text='Ghana', char_interval=CharInterval(start_pos=861, end_pos=866), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=1, group_index=0, description=None, attributes={'type': 'country'}), Extraction(extraction_class='ORG', extraction_text='GoG', char_interval=CharInterval(start_pos=1117, end_pos=1120), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=2, group_index=1, description=None, attributes={'industry': 'government'}), Extraction(extraction_class='ORG', extraction_text='World Bank', char_interval=CharInterval(start_pos=1299, end_pos=1310), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=3, group_index=2, description=None, attributes={'industry': 'financial institution'}), Extraction(extraction_class='ORG', extraction_text='Natural Capital Accounting (NCA) programme', char_interval=CharInterval(start_pos=1468, end_pos=1513), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=4, group_index=3, description=None, attributes={'industry': 'environmental program'}), Extraction(extraction_class='ORG', extraction_text="World Bank's Global Program on Sustainability", char_interval=CharInterval(start_pos=1537, end_pos=1582), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=5, group_index=4, description=None, attributes={'industry': 'environmental program'}), Extraction(extraction_class='ROLE', extraction_text='Government', char_interval=CharInterval(start_pos=1602, end_pos=1612), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=6, group_index=5, description=None, attributes={'relation': 'governing body'}), Extraction(extraction_class='ORG', extraction_text='System of Environmental-Economic Accounting (SEEA)', char_interval=CharInterval(start_pos=1724, end_pos=1773), alignment_status=<AlignmentStatus.MATCH_LESSER: 'match_lesser'>, extraction_index ...

# %%
lx.io.save_annotated_documents([result], output_name="extraction_results.jsonl", output_dir=".")
# Out:
# LangExtract: Saving to extraction_results.jsonl: 1 docs [00:00, 39.03 docs/s]
# ✓ Saved 1 documents to extraction_results.jsonl

# %%
html_content = lx.visualize("extraction_results.jsonl")
with open("visualization.html", "w") as f:
    if hasattr(html_content, 'data'):
        f.write(html_content.data)  # For Jupyter/Colab
    else:
        f.write(html_content)

print("Extraction complete. Check 'extraction_results.jsonl' and 'visualization.html'")
# Out:
# LangExtract: Loading extraction_results.jsonl: 100%|██████████| 28.5k/28.5k [00:00<00:00, 25.1MB/s]
# ✓ Loaded 1 documents from extraction_results.jsonl
# Extraction complete. Check 'extraction_results.jsonl' and 'visualization.html'

# %%
from google.colab import files
files.download("visualization.html")
files.download("extraction_results.jsonl")
